# %%
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np
import csv

netSciencePath = r"/Users/sunce/Desktop/416FinalProject/netscience/netscience.gml"
InternetPath = r"/Users/sunce/Desktop/416FinalProject/as-22july06/as-22july06.gml"

# %%
netScienceGraphNx = nx.read_gml(netSciencePath)
InternetGraphNx = nx.read_gml(InternetPath)

# %%
import nxmetis

# %%
import sys,os

data_path = os.getcwd()

try:
    import localgraphclustering as lgc
except:
    # when the package is not installed, import the local version instead. 
    # the notebook must be placed in the original "notebooks/" folder
    sys.path.append("../")
    import localgraphclustering as lgc

# %%
import time
import numpy as np

import matplotlib.pyplot as plt

# %%
NetScienceGraph = lgc.GraphLocal(os.path.join(data_path,netSciencePath),'gml')
InternetGraph = lgc.GraphLocal(os.path.join(data_path,InternetPath),'gml')
# Out:
# /Users/sunce/anaconda3/lib/python3.6/site-packages/localgraphclustering/GraphLocal.py:190: UserWarning:
#
# Loading a gml is not efficient, we suggest using an edgelist format for this API.

# %%
clustersInternet = []

ksizeInternet = []
conductanceInternet = []

for i in range(0,22693):
    ref_node = [i]
    if i%1000 == 0:
        print(i)
    output_pr_clustering_Internet = lgc.spectral_clustering(InternetGraph,ref_node,method="acl_weighted",iterations=100000)
    if output_pr_clustering_Internet[1] != 0.0:
        clustersInternet.append(output_pr_clustering_Internet[0])
        ksizeInternet.append(len(output_pr_clustering_Internet[0]))
        conductanceInternet.append(output_pr_clustering_Internet[1])
    

print(len(ksizeInternet))
print(len(clustersInternet))
# Out:
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 22693
# 22693

# %%
MinnPath = r"/Users/sunce/Desktop/416FinalProject/minnesota.edgelist"
MinnGraphNx = nx.read_weighted_edgelist(MinnPath,nodetype = int)
print(len(MinnGraphNx.nodes))
print(len(MinnGraphNx.edges))
# Out:
# 2642
# 3303

# %%
# tempNetScience = nx.read_gml(netSciencePath,label="id")

# %%
clusters_mqi_Internet = []
ksize_mqi_Internet = []
conductance_mqi_Internet = []
ref_node_new_Internet = []

for i in range(0,14000):
    ref_node_new_Internet.append(i)
    
for i in range(0,50):
    if i != 0:
        for j in range(0,173):
            ref_node_new_Internet.pop(j)
        for j in range(14000+(i-1)*173,14000+(i-1)*173+173):
            ref_node_new_Internet.append(j)
    
    output_mqi_Internet = lgc.flow_clustering(InternetGraph,ref_node_new_Internet,method="mqi" )
    if i%5 == 0:
        print(i)
        print(len(output_mqi_Internet[0]))
        print(output_mqi_Internet[1])   
    if output_mqi_Internet[1] != 0.0:
        clusters_mqi_Internet.append(output_mqi_Internet[0])
        ksize_mqi_Internet.append(len(output_mqi_Internet[0]))
        conductance_mqi_Internet.append(output_mqi_Internet[1])

print(len(ksize_mqi_Internet))
print(len(conductance_mqi_Internet))
# Out:
# 0
# 4
# 0.09090909090909091
# 5
# 10
# 0.09090909090909091
# 10
# 10
# 0.09090909090909091
# 15
# 466
# 0.07988165680473373
# 20
# 27
# 0.05454545454545454
# 25
# 27
# 0.05454545454545454
# 30
# 27
# 0.05454545454545454
# 35
# 27
# 0.05454545454545454
# 40
# 27
# 0.05454545454545454
# 45
# 27
# 0.05454545454545454
# 50
# 50

# %%
# plt.loglog(ksizeInternet,conductanceInternet,'bo',ksize_mqi_Internet,conductance_mqi_Internet,'ro')

ref_node_new_Internet = []
tempksize = []
tempConductance = []

for i in range(0,50):
    tempksize.append(ksize_mqi_Internet[i])
    
for i in range(0,50):
    tempConductance.append(conductance_mqi_Internet[i])

ksize_mqi_Internet = tempksize
conductance_mqi_Internet = tempConductance

for i in range(0,12000):
    ref_node_new_Internet.append(i)
    
for i in range(0,50):
    if i != 0:
        for j in range(0,200):
            ref_node_new_Internet.pop(j)
        for j in range(12000+(i-1)*200,12000+(i-1)*200+200):
            ref_node_new_Internet.append(j)
    
    output_mqi_Internet = lgc.flow_clustering(InternetGraph,ref_node_new_Internet,method="mqi" )
    if i%5 == 0:
        print(i)
        print(len(output_mqi_Internet[0]))
        print(output_mqi_Internet[1])   
    if output_mqi_Internet[1] != 0.0:
        clusters_mqi_Internet.append(output_mqi_Internet[0])
        ksize_mqi_Internet.append(len(output_mqi_Internet[0]))
        conductance_mqi_Internet.append(output_mqi_Internet[1])

print(len(ksize_mqi_Internet))
print(len(conductance_mqi_Internet))
# Out:
# 0
# 4
# 0.09090909090909091
# 5
# 4
# 0.09090909090909091
# 10
# 4
# 0.09090909090909091
# 15
# 4
# 0.09090909090909091
# 20
# 4
# 0.09090909090909091
# 25
# 27
# 0.05454545454545454
# 30
# 27
# 0.05454545454545454
# 35
# 27
# 0.05454545454545454
# 40
# 27
# 0.05454545454545454
# 45
# 9
# 0.07142857142857142
# 100
# 100

# %%
# plt.loglog(ksize_mqi_Internet,conductance_mqi_Internet,'ro')
ref_node_new_Internet = []
for i in range(0,11000):
    ref_node_new_Internet.append(i)
    
for i in range(0,50):
    if i != 0:
        for j in range(0,233):
            ref_node_new_Internet.pop(j)
        for j in range(11000+(i-1)*233,11000+(i-1)*233+233):
            ref_node_new_Internet.append(j)
    
    output_mqi_Internet = lgc.flow_clustering(InternetGraph,ref_node_new_Internet,method="mqi" )
    if i%10 == 0:
        print(i)
        print(len(output_mqi_Internet[0]))
        print(output_mqi_Internet[1])   
    if output_mqi_Internet[1] != 0.0:
        clusters_mqi_Internet.append(output_mqi_Internet[0])
        ksize_mqi_Internet.append(len(output_mqi_Internet[0]))
        conductance_mqi_Internet.append(output_mqi_Internet[1])

print(len(ksize_mqi_Internet))
print(len(conductance_mqi_Internet))

ref_node_new_Internet = []
for i in range(0,10000):
    ref_node_new_Internet.append(i)
    
for i in range(0,50):
    if i != 0:
        for j in range(0,253):
            ref_node_new_Internet.pop(j)
        for j in range(10000+(i-1)*253,10000+(i-1)*253+253):
            ref_node_new_Internet.append(j)
    
    output_mqi_Internet = lgc.flow_clustering(InternetGraph,ref_node_new_Internet,method="mqi" )
    if i%10 == 0:
        print(i)
        print(len(output_mqi_Internet[0]))
        print(output_mqi_Internet[1])   
    if output_mqi_Internet[1] != 0.0:
        clusters_mqi_Internet.append(output_mqi_Internet[0])
        ksize_mqi_Internet.append(len(output_mqi_Internet[0]))
        conductance_mqi_Internet.append(output_mqi_Internet[1])

print(len(ksize_mqi_Internet))
print(len(conductance_mqi_Internet))
# Out:
# 0
# 11
# 0.13043478260869565
# 10
# 4
# 0.09090909090909091
# 20
# 4
# 0.09090909090909091
# 30
# 27
# 0.05454545454545454
# 40
# 9
# 0.07142857142857142
# 150
# 150
# 0
# 18
# 0.2
# 10
# 4
# 0.09090909090909091
# 20
# 4
# 0.09090909090909091
# 30
# 27
# 0.05454545454545454
# 40
# 9
# 0.07142857142857142
# 200
# 200

# %%
# plt.loglog(ksize_mqi_Internet,conductance_mqi_Internet,'ro')
ref_node_new_Internet = []
for i in range(0,9000):
    ref_node_new_Internet.append(i)
    
for i in range(0,50):
    if i != 0:
        for j in range(0,273):
            ref_node_new_Internet.pop(j)
        for j in range(9000+(i-1)*273,9000+(i-1)*273+273):
            ref_node_new_Internet.append(j)
    
    output_mqi_Internet = lgc.flow_clustering(InternetGraph,ref_node_new_Internet,method="mqi" )
    if i%10 == 0:
        print(i)
        print(len(output_mqi_Internet[0]))
        print(output_mqi_Internet[1])   
    if output_mqi_Internet[1] != 0.0:
        clusters_mqi_Internet.append(output_mqi_Internet[0])
        ksize_mqi_Internet.append(len(output_mqi_Internet[0]))
        conductance_mqi_Internet.append(output_mqi_Internet[1])

print(len(ksize_mqi_Internet))
print(len(conductance_mqi_Internet))

ref_node_new_Internet = []
for i in range(0,8000):
    ref_node_new_Internet.append(i)
    
for i in range(0,50):
    if i != 0:
        for j in range(0,293):
            ref_node_new_Internet.pop(j)
        for j in range(8000+(i-1)*293,8000+(i-1)*293+293):
            ref_node_new_Internet.append(j)
    
    output_mqi_Internet = lgc.flow_clustering(InternetGraph,ref_node_new_Internet,method="mqi" )
    if i%10 == 0:
        print(i)
        print(len(output_mqi_Internet[0]))
        print(output_mqi_Internet[1])   
    if output_mqi_Internet[1] != 0.0:
        clusters_mqi_Internet.append(output_mqi_Internet[0])
        ksize_mqi_Internet.append(len(output_mqi_Internet[0]))
        conductance_mqi_Internet.append(output_mqi_Internet[1])

print(len(ksize_mqi_Internet))
print(len(conductance_mqi_Internet))
# Out:
# 0
# 15
# 0.2
# 10
# 4
# 0.09090909090909091
# 20
# 4
# 0.09090909090909091
# 30
# 27
# 0.05454545454545454
# 40
# 9
# 0.07142857142857142
# 250
# 250
# 0
# 15
# 0.2
# 10
# 11
# 0.13043478260869565
# 20
# 4
# 0.09090909090909091
# 30
# 4
# 0.09090909090909091
# 40
# 9
# 0.1111111111111111
# 300
# 300

# %%
ref_node_new_Internet = []
for i in range(0,6000):
    ref_node_new_Internet.append(i)
    
for i in range(0,50):
    if i != 0:
        for j in range(0,333):
            ref_node_new_Internet.pop(j)
        for j in range(6000+(i-1)*333,6000+(i-1)*333+333):
            ref_node_new_Internet.append(j)
    
    output_mqi_Internet = lgc.flow_clustering(InternetGraph,ref_node_new_Internet,method="mqi" )
    if i%10 == 0:
        print(i)
        print(len(output_mqi_Internet[0]))
        print(output_mqi_Internet[1])   
    if output_mqi_Internet[1] != 0.0:
        clusters_mqi_Internet.append(output_mqi_Internet[0])
        ksize_mqi_Internet.append(len(output_mqi_Internet[0]))
        conductance_mqi_Internet.append(output_mqi_Internet[1])

ref_node_new_Internet = []
for i in range(0,13000):
    ref_node_new_Internet.append(i)
    
for i in range(0,50):
    if i != 0:
        for j in range(0,193):
            ref_node_new_Internet.pop(j)
        for j in range(13000+(i-1)*193,13000+(i-1)*193+193):
            ref_node_new_Internet.append(j)
    
    output_mqi_Internet = lgc.flow_clustering(InternetGraph,ref_node_new_Internet,method="mqi" )
    if i%10 == 0:
        print(i)
        print(len(output_mqi_Internet[0]))
        print(output_mqi_Internet[1])   
    if output_mqi_Internet[1] != 0.0:
        clusters_mqi_Internet.append(output_mqi_Internet[0])
        ksize_mqi_Internet.append(len(output_mqi_Internet[0]))
        conductance_mqi_Internet.append(output_mqi_Internet[1])
# Out:
# 0
# 5
# 0.2
# 10
# 92
# 0.3333333333333333
# 20
# 4
# 0.09090909090909091
# 30
# 4
# 0.09090909090909091
# 40
# 9
# 0.1111111111111111
# 0
# 4
# 0.09090909090909091
# 10
# 10
# 0.09090909090909091
# 20
# 4
# 0.09090909090909091
# 30
# 27
# 0.05454545454545454
# 40
# 27
# 0.05454545454545454

# %%
plt.loglog(ksizeInternet,conductanceInternet,'bo',ksize_mqi_Internet,conductance_mqi_Internet,'ro')
plt.title("Internet Graph")
plt.xlabel("number of nodes in the cluster")
plt.ylabel("conductance of cluster")
plt.gca().legend(('local spectral clustering','Metris+MQI'))

# %%
# Out:
# [array([0, 1], dtype=uint32), array([1, 0], dtype=uint32), array([1, 0], dtype=uint32), array([4, 3, 2], dtype=uint32), array([5, 4, 3, 2], dtype=uint32)]

# %%
# Feiyang Jin, Monday, starts here

MinnPath = r"/Users/sunce/Desktop/416FinalProject/minnesota.edgelist"
MinnGraphNx = nx.read_weighted_edgelist(MinnPath,nodetype = int)
print(len(MinnGraphNx.nodes))
print(len(MinnGraphNx.edges))
# Out:
# 2642
# 3303

# %%
G = lgc.GraphLocal(os.path.join(data_path,MinnPath),'edgelist',remove_whitespace=True)
ksizeTestNew = []
conductanceTestNew = []

ref_node_new = []
for i in range (0,330):
    ref_node_new.append(i)
    
output_mqitest = lgc.flow_clustering(G,ref_node_new,method="mqi")

clustersMinnesota = []
ksizeMinnesota = []
conductanceMinnesota = []
ref_node_new_Minnesota = []

for i in range(0,2600):
    ref_node_new_Minnesota = [i]
    output_clustering_Minnesota = lgc.spectral_clustering(G,ref_node_new_Minnesota,method="acl_weighted",iterations=100000)
    if output_clustering_Minnesota[1] != 0.0:
        clustersMinnesota.append(output_clustering_Minnesota[0])
        ksizeMinnesota.append(len(output_clustering_Minnesota[0]))
        conductanceMinnesota.append(output_clustering_Minnesota[1])
    

print(len(ksizeMinnesota))
print(len(clustersMinnesota))
# Out:
# /Users/sunce/anaconda3/lib/python3.6/site-packages/localgraphclustering/flow_clustering.py:46: UserWarning:
#
# The weights of the graph will be discarded. Use "crd" if you want to keep them.
#
# /Users/sunce/anaconda3/lib/python3.6/site-packages/localgraphclustering/spectral_clustering.py:91: UserWarning:
#
# The weights of the graph will be discarded. Use approximate_PageRank_weighted instead if you want to keep the edge weights.
#
# /Users/sunce/anaconda3/lib/python3.6/site-packages/localgraphclustering/approximate_PageRank.py:110: UserWarning:
#
# The weights of the graph will be discarded. Use approximate_PageRank_weighted instead if you want to keep the edge weights.
# 2598
# 2598

# %%
averagePathLenListJinMinnSpec = []
for cluster in clustersMinnesota:
    subGJin = MinnGraphNx.subgraph(cluster)
    ASPval = nx.average_shortest_path_length(subGJin)
    averagePathLenListJinMinnSpec.append(ASPval)

print(max(averagePathLenListJinMinnSpec))
xIndex = []
for cluster in clustersMinnesota:
    xIndex.append(len(cluster))
# Out:
# 12.909917057338623

# %%
clusters_mqi_Minnesota = []
ksize_mqi_Minnesota = []
conductance_mqi_Minnesota = []
ref_node_mqi_Minnesota = []

for i in range (0,330):
    ref_node_mqi_Minnesota.append(i)

for j in range(0,2270):
    ref_node_mqi_Minnesota.pop(0)
    ref_node_mqi_Minnesota.append(j+330)
    
    output_mqi_Minnesota = lgc.flow_clustering(G,ref_node_mqi_Minnesota,method="mqi")
    if output_mqi_Minnesota[1] != 0.0:
        clusters_mqi_Minnesota.append(output_mqi_Minnesota[0])
        ksize_mqi_Minnesota.append(len(output_mqi_Minnesota[0]))
        conductance_mqi_Minnesota.append(output_mqi_Minnesota[1])
# Out:
# /Users/sunce/anaconda3/lib/python3.6/site-packages/localgraphclustering/flow_clustering.py:46: UserWarning:
#
# The weights of the graph will be discarded. Use "crd" if you want to keep them.

# %%
averagePathLenListJinMinnMqi = []
for cluster in clusters_mqi_Minnesota:
    subGJin = MinnGraphNx.subgraph(cluster)
    ASPval = nx.average_shortest_path_length(subGJin)
    averagePathLenListJinMinnMqi.append(ASPval)

# %%
print(max(averagePathLenListJinMinnMqi))
xIndexMqi = []

for cluster in clusters_mqi_Minnesota:
    xIndexMqi.append(len(cluster))

plt.loglog(xIndex,averagePathLenListJinMinnSpec,'bo',xIndexMqi,averagePathLenListJinMinnMqi,'ro')
plt.title("Minnesota Graph")
plt.xlabel("number of nodes in the cluster")
plt.ylabel("average path length in cluster")
plt.gca().legend(('local spectral clustering','Metris+MQI'))
# Out:
# 21.83534320967935

# %%
plt.loglog(ksizeMinnesota,conductanceMinnesota,'bo',ksize_mqi_Minnesota,conductance_mqi_Minnesota,'ro')
plt.title("Minnesota Graph")
plt.xlabel("number of nodes in the cluster")
plt.ylabel("conductance of cluster")
plt.gca().legend(('local spectral clustering','Metris+MQI'))

# %%
for i in range(len(clusters_mqi_Minnesota)):
    print(i)
    print(ksize_mqi_Minnesota[i])
    print(averagePathLenListJinMinnMqi[i])
    
# print(len(clusters_mqi_Minnesota[1300]))
clusters_mqi_Sub = MinnGraphNx.subgraph(clusters_mqi_Minnesota[51])
nx.draw(clusters_mqi_Sub)
# 51
# 86
# 13.984952120383037
# Out:
# 0
# 194
# 10.658458415682922
# 1
# 298
# 15.068673310284048
# 2
# 313
# 15.998996477430982
# 3
# 313
# 15.998996477430982
# 4
# 312
# 16.012078489570452
# 5
# 316
# 15.994735784609203
# 6
# 314
# 15.959199039498586
# 7
# 314
# 15.959199039498586
# 8
# 312
# 16.406484458735264
# 9
# 312
# 16.406484458735264
# 10
# 310
# 16.549243136026725
# 11
# 310
# 16.549243136026725
# 12
# 309
# 16.562602446097593
# 13
# 326
# 16.600509674374706
# 14
# 326
# 16.600509674374706
# 15
# 324
# 16.547184955853687
# 16
# 325
# 16.574396961063627
# 17
# 323
# 16.606618848912564
# 18
# 134
# 11.626865671641792
# 19
# 134
# 11.626865671641792
# 20
# 134
# 11.626865671641792
# 21
# 134
# 11.626865671641792
# 22
# 134
# 11.626865671641792
# 23
# 99
# 10.481137909709338
# 24
# 99
# 10.481137909709338
# 25
# 99
# 10.481137909709338
# 26
# 98
# 10.387123921733641
# 27
# 98
# 10.387123921733641
# 28
# 98
# 10.387123921733641
# 29
# 98
# 10.387123921733641
# 30
# 98
# 10.387123921733641
# 31
# 98
# ...

# %%
for i in range(len(clustersMinnesota)):
    print(i)
    print(ksizeMinnesota[i])
    print(averagePathLenListJinMinnSpec[i])

print(len(clustersMinnesota[2537]))
clusterSubG = MinnGraphNx.subgraph(clustersMinnesota[2537])
nx.draw(clusterSubG)
# Out:
# 0
# 41
# 5.303658536585366
# 1
# 76
# 7.033333333333333
# 2
# 74
# 7.540170307293595
# 3
# 74
# 7.540170307293595
# 4
# 133
# 10.562200956937799
# 5
# 117
# 10.24255820807545
# 6
# 41
# 5.303658536585366
# 7
# 41
# 5.303658536585366
# 8
# 114
# 10.11380220462661
# 9
# 134
# 10.607002581079565
# 10
# 140
# 10.419938335046249
# 11
# 74
# 7.540170307293595
# 12
# 128
# 10.635211614173228
# 13
# 41
# 5.303658536585366
# 14
# 80
# 7.1579113924050635
# 15
# 83
# 7.345577431677931
# 16
# 76
# 7.033333333333333
# 17
# 120
# 10.22829131652661
# 18
# 120
# 10.238375350140055
# 19
# 109
# 9.564390078151545
# 20
# 78
# 7.337995337995338
# 21
# 79
# 7.339824732229795
# 22
# 94
# 8.760924273621598
# 23
# 77
# 7.273069036226931
# 24
# 11
# 2.3636363636363638
# 25
# 11
# 2.3636363636363638
# 26
# 11
# 2.3636363636363638
# 27
# 11
# 2.3636363636363638
# 28
# 11
# 2.3636363636363638
# 29
# 11
# 2.3636363636363638
# 30
# 56
# 6.66038961038961
# 31
# 72
# 6.841940532081377
# 32
# 93
# 7.737494156147733
# ...
